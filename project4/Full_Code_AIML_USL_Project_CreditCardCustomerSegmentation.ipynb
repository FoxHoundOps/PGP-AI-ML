# %% [markdown]
# **Learner Name: Damian Najera**

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context
#
#
# AllLife Bank wants to focus on its credit card customer base in the next financial year. They have been advised by their marketing research team, that the penetration in the market can be improved. Based on this input, the Marketing team proposes to run personalized campaigns to target new customers as well as upsell to existing customers. Another insight from the market research was that the customers perceive the support services of the back poorly. Based on this, the Operations team wants to upgrade the service delivery model, to ensure that customer queries are resolved faster. Head of Marketing and Head of Delivery both decide to reach out to the Data Science team for help
#
#
# ### Objective
#
# To identify different segments in the existing customer, based on their spending patterns as well as past interaction with the bank, using clustering algorithms, and provide recommendations to the bank on how to better market to and service these customers.
#
#
# ###  Data Description
#
# The data provided is of various customers of a bank and their financial attributes like credit limit, the total number of credit cards the customer has, and different channels through which customers have contacted the bank for any queries (including visiting the bank, online and through a call center).
#
# **Data Dictionary**
#
# - Sl_No: Primary key of the records
# - Customer Key: Customer identification number
# - Average Credit Limit: Average credit limit of each customer for all credit cards
# - Total credit cards: Total number of credit cards possessed by the customer
# - Total visits bank: Total number of Visits that customer made (yearly) personally to the bank
# - Total visits online: Total number of visits or online logins made by the customer (yearly)
# - Total calls made: Total number of calls made by the customer to the bank or its customer service department (yearly)

# %% [markdown]
# ## Importing necessary libraries

# %%
# this will help in making the Python code more structured automatically (good coding practice)
# %load_ext nb_black

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)

# to scale the data using z-score
from sklearn.preprocessing import StandardScaler

# to compute distances
from scipy.spatial.distance import cdist, pdist

# to perform k-means clustering and compute silhouette scores
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# to visualize the elbow curve and silhouette scores
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

# to perform hierarchical clustering, compute cophenetic correlation, and create dendrograms
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet

# to suppress warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the dataset

# %%
data = pd.read_excel('Credit+Card+Customer+Data.xlsx')

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### Checking the shape of the dataset

# %%
# checking shape of the data
print(f"There are {data.shape[0]} rows and {data.shape[1]} columns.")
# Out:
# There are 660 rows and 7 columns.

# %% [markdown]
# ### Displaying few rows of the dataset

# %%
# viewing the first 5 rows of the data
data.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %% [markdown]
# ### Creating a copy of original data

# %%
# copying the data to another variable to avoid any changes to original data
df = data.copy()

# %%
# fixing column names
df.columns = [c.replace(" ", "_") for c in df.columns]

# %% [markdown]
# ### Checking the data types of the columns for the dataset

# %%
# checking datatypes and number of non-null values for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sl_No                660 non-null    int64
#  1   Customer_Key         660 non-null    int64
#  2   Avg_Credit_Limit     660 non-null    int64
#  3   Total_Credit_Cards   660 non-null    int64
#  4   Total_visits_bank    660 non-null    int64
#  5   Total_visits_online  660 non-null    int64
#  6   Total_calls_made     660 non-null    int64
# dtypes: int64(7)
# memory usage: 36.2 KB

# %% [markdown]
# - All the columns in the data are numeric.

# %% [markdown]
# ### Checking the missing values

# %%
# checking for missing values
df.isnull().sum()
# Out:
# Sl_No                  0
# Customer_Key           0
# Avg_Credit_Limit       0
# Total_Credit_Cards     0
# Total_visits_bank      0
# Total_visits_online    0
# Total_calls_made       0
# dtype: int64

# %% [markdown]
# #### Observations
# There are no missing values in the data.

# %%
# checking the number of unique values in each column
df.nunique()
# Out:
# Sl_No                  660
# Customer_Key           655
# Avg_Credit_Limit       110
# Total_Credit_Cards      10
# Total_visits_bank        6
# Total_visits_online     16
# Total_calls_made        11
# dtype: int64

# %% [markdown]
# ### Checking for duplicates values

# %% [markdown]
# **Let's look at the duplicate values in the *Customer_Key* column closely.**

# %%
# getting the count for each unique value in Customer_Key
data_grouped = df.groupby("Customer_Key").count()

for i in data_grouped.loc[data_grouped.Sl_No >= 2].index:
    display(df.loc[df.Customer_Key == i])
# Out:
#      Sl_No  Customer_Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 48      49         37252              6000                   4
# 432    433         37252             59000                   6
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 48                   0                    2                 8
# 432                  2                    1                 2
#      Sl_No  Customer_Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 4        5         47437            100000                   6
# 332    333         47437             17000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 4                    0                   12                 3
# 332                  3                    1                 0
#      Sl_No  Customer_Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 411    412         50706             44000                   4
# 541    542         50706             60000                   7
#
# ...

# %% [markdown]
# #### Observations
#  This analysis reveals that there are customers with the same 'Customer Key' but different values in other columns.
#
# Here are the 'Customer Key' values that appear twice:
#
#     37252
#     47437
#     50706
#     96929
#     97935
#
# For each of these 'Customer Key' values, the two corresponding rows have different values in most of the other columns. This suggests that these are not exact duplicates but rather different records associated with the same customer.
#
# Given the context and objective, let us treat each entry as a separate customer for the purpose of the analysis. We will assume that each entry represents a significantly different behavior pattern that could belong to a different customer segment.

# %%
df.drop(columns=["Sl_No"], inplace=True) 
df.drop(columns=["Customer_Key"], inplace=True)

# %% [markdown]
# ### Statistical summary of the dataset

# %%
# Let's look at the statistical summary of the data
df.describe().T
# Out:
#                      count          mean           std     min      25%  \
# Avg_Credit_Limit     660.0  34574.242424  37625.487804  3000.0  10000.0
# Total_Credit_Cards   660.0      4.706061      2.167835     1.0      3.0
# Total_visits_bank    660.0      2.403030      1.631813     0.0      1.0
# Total_visits_online  660.0      2.606061      2.935724     0.0      1.0
# Total_calls_made     660.0      3.583333      2.865317     0.0      1.0
#
#                          50%      75%       max
# Avg_Credit_Limit     18000.0  48000.0  200000.0
# Total_Credit_Cards       5.0      6.0      10.0
# Total_visits_bank        2.0      4.0       5.0
# Total_visits_online      2.0      4.0      15.0
# Total_calls_made         3.0      5.0      10.0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### The below functions need to be defined to carry out the Exploratory Data Analysis.

# %%
# function to plot a boxplot and a histogram along the same scale.
def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# **Let's see the distribution of different variables in the dataset**

# %%
for col in df.columns:
    histogram_boxplot(data, col)

# %%
for col in df.columns.tolist()[1:]:
    labeled_barplot(df, col, perc=True)

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 15))
fig.suptitle("CDF plot of numerical variables", fontsize=20)

counter = 0

for ii in range(3):
    sns.ecdfplot(data=df, ax=axes[ii][0], x=df.columns.tolist()[counter])
    counter = counter + 1
    if counter != 5:
        sns.ecdfplot(data=df, ax=axes[ii][1], x=df.columns.tolist()[counter])
        counter = counter + 1
    else:
        pass

fig.tight_layout(pad=2.0)

# %% [markdown]
# #### Observations:
# - Avg_Credit_Limit: Most customers have a credit limit around 10,000 to 50,000. However, there are quite a few customers with a higher credit limit, even up to 200,000. These customers can be considered outliers as they are far from the majority of customers.
#
# - Total_Credit_Cards: The number of credit cards customers have is almost normally distributed, with most customers having around 4 to 6 cards.
#
# - Total_visits_bank: Customers typically visit the bank 0 to 4 times a year, with the most common being around 2 visits.
#
# - Total_visits_online: Most customers visit the bank online 0 to 4 times a year, but there are some outliers who visit very frequently (up to 15 times a year).
#
# - Total_calls_made: The number of calls made by customers varies widely, with a significant number of customers making 0 to 4 calls a year. However, there are some who make as many as 10 calls a year.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# **Let's check for correlations.**

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
sns.pairplot(data=df, diag_kind="kde")
plt.show()

# %%
sns.pairplot(
    data=df[
        [
            "Total_visits_bank",
            "Total_visits_online",
            "Total_calls_made",
            "Total_Credit_Cards",
        ]
    ],
    hue="Total_Credit_Cards",
)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection="3d")

x = df["Total_visits_bank"]
y = df["Total_visits_online"]
z = df["Total_calls_made"]


ax.scatter(x, y, z, marker=".")
ax.set_xlabel("Total_visits_bank")
ax.set_ylabel("Total_visits_online")
ax.set_zlabel("Total_calls_made")
ax.view_init(azim=60)
plt.show()

# %% [markdown]
# #### Observations:
# - Avg_Credit_Limit has a strong positive correlation with Total_Credit_Cards and Total_visits_online. This suggests that customers who have a higher credit limit tend to have more credit cards and make more online visits.
# - Total_Credit_Cards has a moderate negative correlation with Total_calls_made. This indicates that customers with more credit cards tend to make fewer calls to the bank.
# - Total_visits_bank has a moderate negative correlation with Total_visits_online and Total_calls_made. This means that customers who frequently visit the bank in person tend to make fewer online visits and calls.

# %% [markdown]
# ### Questions

# %% [markdown]
# 1. How is the distrubution of average credit limit of customer?
#
# `The distribution of the 'Average Credit Limit' is highly skewed to the right. The majority of customers have a lower average credit limit, while a small number of customers have a very high average credit limit.`

# %%
# Plotting distribution of 'Avg_Credit_Limit'
plt.figure(figsize=(10,6))
sns.histplot(data['Avg_Credit_Limit'], kde=True)
plt.title('Distribution of Average Credit Limit')
plt.xlabel('Average Credit Limit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2. What percenatage of the customers have never made a service-related call to the bank?

# %%
# calculate the percentage of customers who have never made a service-related call to the bank
no_calls_percentage = (df[df['Total_calls_made'] == 0].shape[0] / df.shape[0]) * 100
no_calls_percentage
# Out:
# 14.696969696969697

# %% [markdown]
# 3. What percentage of customers have never logged in to the online portal?

# %%
# calculating the percentage of customers who have never logged in to the online portal
no_online_visits_percentage = (df[df['Total_visits_online'] == 0].shape[0] / df.shape[0]) * 100
no_online_visits_percentage
# Out:
# 21.818181818181817

# %% [markdown]
# 4. How many customers have never visited bank?

# %%
# calculating the number of customers who have never visited the bank
no_bank_visits = data[data['Total_visits_bank'] == 0].shape[0]
no_bank_visits
# Out:
# 100

# %% [markdown]
# 5. How are the different variables correlated with each other?
#
# `See the graphs above in the Bivariate Analysis for reference. As stated in the Observations above: Avg_Credit_Limit has a strong positive correlation with Total_Credit_Cards and Total_visits_online. This suggests that customers who have a higher credit limit tend to have more credit cards and make more online visits. Total_Credit_Cards has a moderate negative correlation with Total_calls_made. This indicates that customers with more credit cards tend to make fewer calls to the bank. Total_visits_bank has a moderate negative correlation with Total_visits_online and Total_calls_made. This means that customers who frequently visit the bank in person tend to make fewer online visits and calls.`

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Outlier Detection
#
# - Let's find outliers in the data using z-score with a threshold of 3.

# %%
threshold = 3 
outlier = {}
for col in df.columns:
    i = df[col]
    mean = np.mean(df[col])
    std = np.std(df[col])
    list1 = []
    for v in i:
        z = (v - mean) / std
        if z > threshold:
            list1.append(v)
    list1.sort()
    outlier[i.name] = list1

print("The following are the outliers in the data:")
for key, value in outlier.items():
    print("\n", key, ":", value)
# Out:
# The following are the outliers in the data:
#
#  Avg_Credit_Limit : [153000, 155000, 156000, 156000, 157000, 158000, 163000, 163000, 166000, 166000, 167000, 171000, 172000, 172000, 173000, 176000, 178000, 183000, 184000, 186000, 187000, 195000, 195000, 200000]
#
#  Total_Credit_Cards : []
#
#  Total_visits_bank : []
#
#  Total_visits_online : [12, 12, 12, 12, 12, 12, 13, 13, 13, 13, 13, 14, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15]
#
#  Total_calls_made : []

# %% [markdown]
# #### Observations
# - Avg_Credit_Limit: The outliers in this column represent customers with a very high credit limit. These customers seem to be high-income individuals or premium customers, and are important as they generate significant revenue.
#
# - Total_visits_online: The outliers in this column represent customers who use the bank's online services frequently. They represent a customer segment that is growing in importance as banking services increasingly move online.
#
# In both cases, the outliers represent significant customer behavior that should not be ignored. They provide valuable insights into different customer segments and can help the bank develop more effective marketing and service strategies.

# %% [markdown]
# ### Scaling
#
# - Let's scale the data before we proceed with clustering.

# %%
# scaling the data before clustering
scaler = StandardScaler()
subset = df[['Avg_Credit_Limit', 'Total_Credit_Cards', 'Total_visits_bank', 'Total_visits_online', 'Total_calls_made']]
subset_scaled = scaler.fit_transform(subset)

# %%
# creating a dataframe of the scaled data
subset_scaled_df = pd.DataFrame(subset_scaled, columns=subset.columns)

# %% [markdown]
# ## K-means Clustering

# %% [markdown]
# ### Checking Elbow Plot

# %%
k_means_df = subset_scaled_df.copy()

# %%
clusters = range(2, 11)
meanDistortions = []

for k in clusters:
    model = KMeans(n_clusters=k, random_state=1)
    model.fit(subset_scaled_df)
    prediction = model.predict(k_means_df)
    distortion = sum(
        np.min(cdist(k_means_df, model.cluster_centers_, "euclidean"), axis=1) ** 2)

    meanDistortions.append(distortion)

    print("Number of Clusters:", k, "\tAverage Distortion:", distortion)

plt.plot(clusters, meanDistortions, "bx-")
plt.xlabel("k")
plt.ylabel("Average Distortion")
plt.title("Selecting k with the Elbow Method", fontsize=20)
plt.show()
# Out:
# Number of Clusters: 2 	Average Distortion: 2040.9898164784947
# Number of Clusters: 3 	Average Distortion: 933.0437490000531
# Number of Clusters: 4 	Average Distortion: 780.773689555177
# Number of Clusters: 5 	Average Distortion: 704.4759188657513
# Number of Clusters: 6 	Average Distortion: 642.4285451423211
# Number of Clusters: 7 	Average Distortion: 600.2307262933779
# Number of Clusters: 8 	Average Distortion: 562.9699837327828
# Number of Clusters: 9 	Average Distortion: 538.1073332196183
# Number of Clusters: 10 	Average Distortion: 516.4200301863631

# %%
model = KMeans(random_state=1)
visualizer = KElbowVisualizer(model, k=(2, 10), timings=True)
visualizer.fit(k_means_df)  # fit the data to the visualizer
visualizer.show()  # finalize and render figure
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### Let's check the silhouette scores

# %%
sil_score = []
cluster_list = range(2, 10)
for n_clusters in cluster_list:
    clusterer = KMeans(n_clusters=n_clusters, random_state=1)
    preds = clusterer.fit_predict((subset_scaled_df))
    score = silhouette_score(k_means_df, preds)
    sil_score.append(score)
    print("For n_clusters = {}, the silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, the silhouette score is 0.41842496663215445)
# For n_clusters = 3, the silhouette score is 0.5157182558881063)
# For n_clusters = 4, the silhouette score is 0.3556670619372605)
# For n_clusters = 5, the silhouette score is 0.2717470361089752)
# For n_clusters = 6, the silhouette score is 0.255906765297388)
# For n_clusters = 7, the silhouette score is 0.2479125425802003)
# For n_clusters = 8, the silhouette score is 0.2270510795671221)
# For n_clusters = 9, the silhouette score is 0.2133916497963662)

# %%
plt.plot(cluster_list, sil_score)
plt.show()

# %% [markdown]
# **Let's visualize the silhouette scores for different number of clusters**

# %%
model = KMeans(random_state=1)
visualizer = KElbowVisualizer(model, k=(2, 10), metric="silhouette", timings=True) 
visualizer.fit(k_means_df)  # fit the data to the visualizer
visualizer.show()  # finalize and render figure
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(3, random_state=1)) 
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 660 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(3, random_state=1))  
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 660 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(3, random_state=1))  
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 660 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# finding optimal no. of clusters with silhouette coefficients
visualizer = SilhouetteVisualizer(KMeans(3, random_state=1))  
visualizer.fit(k_means_df)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 660 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# ### Creating Final Model

# %%
# %%time
kmeans = KMeans(n_clusters=3, random_state=1) 
kmeans.fit(k_means_df)
# Out:
# CPU times: total: 2.69 s
# Wall time: 207 ms
# KMeans(n_clusters=3, random_state=1)

# %%
# creating a copy of the original data
df1 = df.copy()

# adding kmeans cluster labels to the original and scaled dataframes
k_means_df["K_means_segments"] = kmeans.labels_
df1["K_means_segments"] = kmeans.labels_

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# ### Computing Cophenetic Correlation

# %%
hc_df = subset_scaled_df.copy()

# %%
# list of distance metrics
distance_metrics = ["euclidean", "chebyshev", "mahalanobis", "cityblock"]

# list of linkage methods
linkage_methods = ["single", "complete", "average", "weighted"]

high_cophenet_corr = 0
high_dm_lm = [0, 0]

for dm in distance_metrics:
    for lm in linkage_methods:
        Z = linkage(hc_df, metric=dm, method=lm)
        c, coph_dists = cophenet(Z, pdist(hc_df))
        print(
            "Cophenetic correlation for {} distance and {} linkage is {}.".format(
                dm.capitalize(), lm, c
            )
        )
        if high_cophenet_corr < c:
            high_cophenet_corr = c
            high_dm_lm[0] = dm
            high_dm_lm[1] = lm
# Out:
# Cophenetic correlation for Euclidean distance and single linkage is 0.7391220243806552.
# Cophenetic correlation for Euclidean distance and complete linkage is 0.8599730607972423.
# Cophenetic correlation for Euclidean distance and average linkage is 0.8977080867389372.
# Cophenetic correlation for Euclidean distance and weighted linkage is 0.8861746814895477.
# Cophenetic correlation for Chebyshev distance and single linkage is 0.7382354769296767.
# Cophenetic correlation for Chebyshev distance and complete linkage is 0.8533474836336782.
# Cophenetic correlation for Chebyshev distance and average linkage is 0.8974159511838106.
# Cophenetic correlation for Chebyshev distance and weighted linkage is 0.8913624010768603.
# Cophenetic correlation for Mahalanobis distance and single linkage is 0.7058064784553608.
# Cophenetic correlation for Mahalanobis distance and complete linkage is 0.6663534463875372.
# ...

# %%
# printing the combination of distance metric and linkage method with the highest cophenetic correlation
print(
    "Highest cophenetic correlation is {}, which is obtained with {} distance and {} linkage.".format(
        high_cophenet_corr, high_dm_lm[0].capitalize(), high_dm_lm[1]
    )
)
# Out:
# Highest cophenetic correlation is 0.8977080867389372, which is obtained with Euclidean distance and average linkage.

# %% [markdown]
# **Let's explore different linkage methods with Euclidean distance only.**

# %%
# list of linkage methods
linkage_methods = ["single", "complete", "average", "centroid", "ward", "weighted"]

high_cophenet_corr = 0
high_dm_lm = [0, 0]

for lm in linkage_methods:
    Z = linkage(hc_df, metric="euclidean", method=lm)
    c, coph_dists = cophenet(Z, pdist(hc_df))
    print("Cophenetic correlation for {} linkage is {}.".format(lm, c))
    if high_cophenet_corr < c:
        high_cophenet_corr = c
        high_dm_lm[0] = "euclidean"
        high_dm_lm[1] = lm
# Out:
# Cophenetic correlation for single linkage is 0.7391220243806552.
# Cophenetic correlation for complete linkage is 0.8599730607972423.
# Cophenetic correlation for average linkage is 0.8977080867389372.
# Cophenetic correlation for centroid linkage is 0.8939385846326323.
# Cophenetic correlation for ward linkage is 0.7415156284827493.
# Cophenetic correlation for weighted linkage is 0.8861746814895477.

# %%
# printing the combination of distance metric and linkage method with the highest cophenetic correlation
print()
print(
    "Highest cophenetic correlation is {}, which is obtained with {} linkage.".format(
        high_cophenet_corr, high_dm_lm[1]
    )
)
# Out:
# Highest cophenetic correlation is 0.8977080867389372, which is obtained with average linkage.

# %% [markdown]
# ### Checking Dendrograms

# %% [markdown]
# **We see that the cophenetic correlation is maximum with Euclidean distance and average linkage.**
#
#
# **Let's view the dendrograms for the different linkage methods.**

# %%
# list of linkage methods
linkage_methods = ["single", "complete", "average", "centroid", "ward", "weighted"]

# lists to save results of cophenetic correlation calculation
compare_cols = ["Linkage", "Cophenetic Coefficient"]
compare = []

# to create a subplot image
fig, axs = plt.subplots(len(linkage_methods), 1, figsize=(15, 30))

# We will enumerate through the list of linkage methods above
# For each linkage method, we will plot the dendrogram and calculate the cophenetic correlation
for i, method in enumerate(linkage_methods):
    Z = linkage(hc_df, metric="euclidean", method=method)

    dendrogram(Z, ax=axs[i])
    axs[i].set_title(f"Dendrogram ({method.capitalize()} Linkage)")

    coph_corr, coph_dist = cophenet(Z, pdist(hc_df))
    axs[i].annotate(
        f"Cophenetic\nCorrelation\n{coph_corr:0.2f}",
        (0.80, 0.80),
        xycoords="axes fraction",
    )

    compare.append([method, coph_corr])

# %% [markdown]
# **Dendrogram with average linkage shows distinct and separate cluster tree.**

# %%
# create and print a dataframe to compare cophenetic correlations for different linkage methods
df_cc = pd.DataFrame(compare, columns=compare_cols)
df_cc = df_cc.sort_values(by="Cophenetic Coefficient")
df_cc
# Out:
#     Linkage  Cophenetic Coefficient
# 0    single                0.739122
# 4      ward                0.741516
# 1  complete                0.859973
# 5  weighted                0.886175
# 3  centroid                0.893939
# 2   average                0.897708

# %% [markdown]
# ### Creating Final Model

# %%
HCmodel = AgglomerativeClustering(n_clusters=3, affinity="euclidean", linkage="ward") 
HCmodel.fit(hc_df)
# Out:
# AgglomerativeClustering(affinity='euclidean', n_clusters=3)

# %%
# creating a copy of the original data
df2 = df.copy()

# adding hierarchical cluster labels to the original and scaled dataframes
hc_df["HC_segments"] = HCmodel.labels_
df2["HC_segments"] = HCmodel.labels_

# %%
hc_df.head()
# Out:
#    Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0          1.740187           -1.249225          -0.860451
# 1          0.410293           -0.787585          -1.473731
# 2          0.410293            1.058973          -0.860451
# 3         -0.121665            0.135694          -0.860451
# 4          1.740187            0.597334          -1.473731
#
#    Total_visits_online  Total_calls_made  HC_segments
# 0            -0.547490         -1.251537            0
# 1             2.520519          1.891859            1
# 2             0.134290          0.145528            0
# 3            -0.547490          0.145528            0
# 4             3.202298         -0.203739            2

# %%
df2.head()
# Out:
#    Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0            100000                   2                  1
# 1             50000                   3                  0
# 2             50000                   7                  1
# 3             30000                   5                  1
# 4            100000                   6                  0
#
#    Total_visits_online  Total_calls_made  HC_segments
# 0                    1                 0            0
# 1                   10                 9            1
# 2                    3                 4            0
# 3                    1                 4            0
# 4                   12                 3            2

# %%
subset_scaled_df["HC_Clusters"] = HCmodel.labels_
df2["HC_Clusters"] = HCmodel.labels_

# %% [markdown]
# ## Cluster Profiling and Comparison

# %% [markdown]
# ### Cluster Profiling: K-means Clustering

# %%
km_cluster_profile = df1.groupby("K_means_segments").mean()

# %%
km_cluster_profile["count_in_each_segment"] = (
    df1.groupby("K_means_segments")["Avg_Credit_Limit"].count().values  
)

# %%
km_cluster_profile
# Out:
#                   Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# K_means_segments
# 0                     33782.383420            5.515544           3.489637
# 1                     12174.107143            2.410714           0.933036
# 2                    141040.000000            8.740000           0.600000
#
#                   Total_visits_online  Total_calls_made  count_in_each_segment
# K_means_segments
# 0                            0.981865          2.000000                    386
# 1                            3.553571          6.870536                    224
# 2                           10.900000          1.080000                     50

# %% [markdown]
# ### Cluster Profiling: Hierarchical Clustering

# %%
hc_cluster_profile = df2.groupby("HC_segments").mean()

# %%
hc_cluster_profile["count_in_each_segment"] = (
    df2.groupby("HC_segments")["Avg_Credit_Limit"].count().values
)

# %%
hc_cluster_profile
# Out:
#              Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# HC_segments
# 0                33851.948052            5.516883           3.493506
# 1                12151.111111            2.422222           0.937778
# 2               141040.000000            8.740000           0.600000
#
#              Total_visits_online  Total_calls_made  HC_Clusters  \
# HC_segments
# 0                       0.979221          1.994805          0.0
# 1                       3.546667          6.857778          1.0
# 2                      10.900000          1.080000          2.0
#
#              count_in_each_segment
# HC_segments
# 0                              385
# 1                              225
# 2                               50

# %% [markdown]
# ## K-means vs Hierarchical Clustering

# %%
km_cluster_profile.style.highlight_max(color="lightgreen", axis=0)
# Out:
# <style type="text/css">
# #T_f1363_row0_col2, #T_f1363_row0_col5, #T_f1363_row1_col4, #T_f1363_row2_col0, #T_f1363_row2_col1, #T_f1363_row2_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f1363">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1363_level0_col0" class="col_heading level0 col0" >Avg_Credit_Limit</th>
#       <th id="T_f1363_level0_col1" class="col_heading level0 col1" >Total_Credit_Cards</th>
#       <th id="T_f1363_level0_col2" class="col_heading level0 col2" >Total_visits_bank</th>
#       <th id="T_f1363_level0_col3" class="col_heading level0 col3" >Total_visits_online</th>
#       <th id="T_f1363_level0_col4" class="col_heading level0 col4" >Total_calls_made</th>
#       <th id="T_f1363_level0_col5" class="col_heading level0 col5" >count_in_each_segment</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >K_means_segments</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
hc_cluster_profile.style.highlight_max(color="lightgreen", axis=0)
# Out:
# <style type="text/css">
# #T_9cace_row0_col2, #T_9cace_row0_col6, #T_9cace_row1_col4, #T_9cace_row2_col0, #T_9cace_row2_col1, #T_9cace_row2_col3, #T_9cace_row2_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9cace">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cace_level0_col0" class="col_heading level0 col0" >Avg_Credit_Limit</th>
#       <th id="T_9cace_level0_col1" class="col_heading level0 col1" >Total_Credit_Cards</th>
#       <th id="T_9cace_level0_col2" class="col_heading level0 col2" >Total_visits_bank</th>
#       <th id="T_9cace_level0_col3" class="col_heading level0 col3" >Total_visits_online</th>
#       <th id="T_9cace_level0_col4" class="col_heading level0 col4" >Total_calls_made</th>
#       <th id="T_9cace_level0_col5" class="col_heading level0 col5" >HC_Clusters</th>
#       <th id="T_9cace_level0_col6" class="col_heading level0 col6" >count_in_each_segment</th>
#     </tr>
#     <tr>
# ...

# %%
k_means_df.groupby("K_means_segments").mean().plot.bar(figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='K_means_segments'>

# %%
hc_df.groupby("HC_segments").mean().plot.bar(figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='HC_segments'>

# %%
k_means_df.loc[k_means_df["K_means_segments"] == 1, "K_means_segments"] = 3
k_means_df.loc[k_means_df["K_means_segments"] == 2, "K_means_segments"] = 1
k_means_df.loc[k_means_df["K_means_segments"] == 3, "K_means_segments"] = 2
df1["K_means_segments"] = k_means_df["K_means_segments"]

km_cluster_profile = df1.groupby("K_means_segments").mean()
km_cluster_profile["count_in_each_segment"] = (
    df1.groupby("K_means_segments")["Avg_Credit_Limit"].count().values
)

# %%
k_means_df.groupby("K_means_segments").mean().plot.bar(figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='K_means_segments'>

# %% [markdown]
# **Let's create some plots on the original data to understand the customer distribution among the clusters.**

# %%
fig, axes = plt.subplots(1, 5, figsize=(16, 6))
fig.suptitle(
    "Boxplot of numerical variables for each cluster obtained using K-means Clustering",
    fontsize=20,
)

counter = 0

for ii in range(5):
    sns.boxplot(
        ax=axes[ii], y=df1[df1.columns[counter]], x=k_means_df["K_means_segments"]
    )
    counter = counter + 1

fig.tight_layout(pad=2.0)

# %%
fig, axes = plt.subplots(1, 5, figsize=(16, 6))
fig.suptitle(
    "Boxplot of numerical variables for each cluster obtained using Hierarchical Clustering",
    fontsize=20,
)

counter = 0

for ii in range(5):
    sns.boxplot(ax=axes[ii], y=df2[df2.columns[counter]], x=hc_df["HC_segments"])
    counter = counter + 1

fig.tight_layout(pad=2.0)

# %% [markdown]
# ## Actionable Insights and Recommendations

# %% [markdown]
# The bank wants to focus on its credit card customer base, run personalized campaigns to target new customers, upsell to existing customers, and improve its service delivery model.
#
# The cluster profiles for both K-means and Hierarchical Clustering algorithms are almost identical, so I'll base the analysis on either profile.
#
# Cluster 0:
#
#     These customers have an average credit limit around $33,800 and hold about 5.5 credit cards each.
#     They visit the bank in person quite frequently (around 3.5 times a year) and rarely visit online or call the bank.
#     This is the largest segment, consisting of 385 (K-means) or 386 (Hierarchical) customers.
#
# Actionable Insights and Recommendations:
# These customers are potentially older demographics who prefer in-person interactions. They have a decent credit limit and a good number of credit cards, which suggests they are valuable customers for the bank.
#
#     As they frequently visit the bank, offering them personalized services during their visits might be effective.
#     The bank could also consider targeting them with offers that encourage the use of additional banking services or products.
#     Upselling could be done effectively during their in-person visits.
#
# Cluster 1:
#
#     These customers have a lower average credit limit, around $12,100, and hold about 2.4 credit cards each.
#     They don't visit the bank frequently but are more active online and make a substantial number of calls to the bank each year.
#     This segment consists of 224 (K-means) or 225 (Hierarchical) customers.
#
# Actionable Insights and Recommendations:
# These customers are likely to be younger or more tech-savvy, as they prefer online banking and phone calls over in-person visits.
#
#     The bank could target them with online marketing campaigns or offers that encourage the use of online banking features.
#     Given their lower credit limit and fewer credit cards, these customers might be good targets for credit limit increase offers or new credit card offers.
#     As these customers often call the bank, improving call center services could increase their satisfaction and loyalty.
#
# Cluster 2:
#
#     These customers have a significantly higher average credit limit of around $141,040 and hold about 8.7 credit cards each.
#     They rarely visit the bank or make phone calls, but they are very active online.
#     This is the smallest segment, consisting of 50 customers for both algorithms.
#
# Actionable Insights and Recommendations:
# These customers are likely to be high-income individuals or businesses, as indicated by their high credit limit and the number of credit cards they hold.
#
#     Given their preference for online banking, the bank could target them with premium online services or products.
#     These customers could also be interested in high-value banking products or services, such as investment or business banking services.
#     The bank could offer them personalized online support to ensure their queries or issues are resolved quickly and efficiently.

# %% [markdown]
# ___
